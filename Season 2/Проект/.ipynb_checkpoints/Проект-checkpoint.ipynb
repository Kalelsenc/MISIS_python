# %% [markdown]
# Люди во многом ассоциировали себя с песнями и музыкой. Это может улучшить настроение, уменьшить боль и беспокойство и облегчить возможности для эмоционального выражения. Исследования показывают, что музыка может принести пользу нашему физическому и психическому здоровью во многих отношениях.
#
# В последнее время было проведено множество исследований, чтобы понять песни и их популярность на основе определенных факторов. Такие сэмплы песен разбиваются на части, и их параметры записываются для составления таблиц. Прогнозирование популярности песни является основной целью.
#
# Проект простой, но сложный, чтобы предсказать популярность песни на основе энергии, акустики, инструментальности, живости, танцевальности и т. д. Набор данных большой, и его сложность возникает из-за того, что он имеет сильную мультиколлинеарность.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math

df1 = pd.read_csv('song_data.csv', delimiter=',')
df = df1.copy()
df
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  liveness  \
# 0          0.005520         0.496   0.682          0.000029    0.0589
# 1          0.010300         0.542   0.853          0.000000    0.1080
# 2          0.008170         0.737   0.463          0.447000    0.2550
# 3          0.026400         0.451   0.970          0.003550    0.1020
# 4          0.000954         0.447   0.766          0.000000    0.1130
# ...             ...           ...     ...               ...       ...
# 18830      0.893000         0.500   0.151          0.000065    0.1110
# 18831      0.765000         0.495   0.161          0.000001    0.1050
# 18832      0.847000         0.719   0.325          0.000000    0.1250
# 18833      0.945000         0.488   0.326          0.015700    0.1190
# 18834      0.911000         0.640   0.381          0.000254    0.1040
#
#        loudness  speechiness    tempo  audio_valence
# 0        -4.095       0.0294  167.060          0.474
# 1        -6.407       0.0498  105.256          0.370
# 2        -7.828       0.0792  123.881          0.324
# 3        -4.938       0.1070  122.444          0.198
# 4        -5.065       0.0313  172.011          0.574
# ...         ...          ...      ...            ...
# 18830   -16.107       0.0348  113.969          0.300
# 18831   -14.078       0.0301   94.286          0.265
# 18832   -12.222       0.0355  130.534          0.286
# 18833   -12.020       0.0328  106.063          0.323
# 18834   -11.790       0.0302   91.490          0.581
#
# [18835 rows x 12 columns]

# %% [markdown]
# Разберём параметры нашего датасета
#
# - song_name (Название песни) - говорит само за себя, но в нашем исследовании будет удален.
# - song_popularity (Популярность песни) - измеряется от 0 до 100, показывает насколько популярна (100 очень популярная).
# - song_duration_ms - длительность песни в мс.
# - acousticness (Акустичность) - описывает, насколько акустической является песня. Оценка 1 означает, что песня, скорее всего, будет акустической.
# - danceability (Танцевальность) - описывает, насколько трек подходит для танцев, основываясь на сочетании музыкальных элементов, включая темп, стабильность ритма, силу удара и общую регулярность. Значение 0 соответствует наименее танцевальному, а значение 1 наиболее танцевальному.
# - energy (Энергичность) - представляет перцептивную меру интенсивности и активности. Как правило, энергичные треки кажутся быстрыми, громкими и шумными.
# - instrumentalness (Инструментальность) - это значение представляет количество вокала в песне. Чем он ближе к 1, тем инструментальнее песня.
# - liveness (Живость) - это значение описывает вероятность того, что песня была записана с живой аудиторией, значение выше 0,8 дает высокую вероятность того, что трек имеет живой звук.
# - loudness (громкость) - количестов дБ относительно опорного уровня, превышающий опорный со знаком «плюс» (например, +3 дБ), а меньший опорного в децибелах со знаком «минус» (например, −6 дБ).
# - speechiness (Речевость) - определяет наличие произнесенных слов в треке. Если речь песни выше 0,66, она, вероятно, состоит из произнесенных слов, оценка от 0,33 до 0,66 — это песня, которая может содержать как музыку, так и слова, а оценка ниже 0,33 означает, что в песне нет речи.
# - tempo (Темп) - скорость исполнения музыкального произведения, измеряется в ударах в минуту.
# - audio_valence (Валентность) - Показатель от 0,0 до 1,0, описывающий музыкальную позитивность, передаваемую треком. Треки с высокой валентностью звучат более позитивно (например, счастливые, веселые, эйфорические), а треки с низкой валентностью звучат более негативно (например, грустные, подавленные, злые).

# %% [markdown]
# Проанализируем данные

# %%
df.nunique().sort_values()
# Out:
# song_popularity       101
# danceability          849
# energy               1132
# speechiness          1224
# audio_valence        1246
# liveness             1425
# acousticness         3209
# instrumentalness     3925
# loudness             8416
# song_duration_ms    11771
# tempo               12112
# song_name           13070
# dtype: int64

# %%
continuous_features = ['song_popularity', 'danceability', 'energy', 'instrumentalness', 'speechiness', 'audio_valence', 'liveness', 'acousticness', 'loudness','song_duration_ms','tempo']

# %% [markdown]
# Посмотрим на распределения наших параметров

# %%
n=6

clr=['r','g','b','g','b','r']

plt.figure(figsize=[15,4*math.ceil(len(continuous_features)/n)])
for i in range(len(continuous_features)):
    plt.subplot(math.ceil(len(continuous_features)/3),n,i+1)
    sns.histplot(df[continuous_features[i]], bins=10, color=list(np.random.randint([255,255,255])/255))
plt.tight_layout()
plt.show()

plt.figure(figsize=[15,4*math.ceil(len(continuous_features)/n)])
for i in range(len(continuous_features)):
    plt.subplot(math.ceil(len(continuous_features)/3),n,i+1)
    df.boxplot(continuous_features[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# Очень много выбросов, сейчас от них избавимся, а также от дубликатов

# %%
df = df.drop_duplicates(keep='first')
df
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  liveness  \
# 0          0.005520         0.496   0.682          0.000029    0.0589
# 1          0.010300         0.542   0.853          0.000000    0.1080
# 2          0.008170         0.737   0.463          0.447000    0.2550
# 3          0.026400         0.451   0.970          0.003550    0.1020
# 4          0.000954         0.447   0.766          0.000000    0.1130
# ...             ...           ...     ...               ...       ...
# 18830      0.893000         0.500   0.151          0.000065    0.1110
# 18831      0.765000         0.495   0.161          0.000001    0.1050
# 18832      0.847000         0.719   0.325          0.000000    0.1250
# 18833      0.945000         0.488   0.326          0.015700    0.1190
# 18834      0.911000         0.640   0.381          0.000254    0.1040
#
#        loudness  speechiness    tempo  audio_valence
# 0        -4.095       0.0294  167.060          0.474
# 1        -6.407       0.0498  105.256          0.370
# 2        -7.828       0.0792  123.881          0.324
# 3        -4.938       0.1070  122.444          0.198
# 4        -5.065       0.0313  172.011          0.574
# ...         ...          ...      ...            ...
# 18830   -16.107       0.0348  113.969          0.300
# 18831   -14.078       0.0301   94.286          0.265
# 18832   -12.222       0.0355  130.534          0.286
# 18833   -12.020       0.0328  106.063          0.323
# 18834   -11.790       0.0302   91.490          0.581
#
# [14926 rows x 12 columns]

# %%
features1 = continuous_features

for i in features1:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    df = df[df[i] <= (Q3+(1.5*IQR))]
    df = df[df[i] >= (Q1-(1.5*IQR))]
    df = df.reset_index(drop=True)
display(df.head())
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  Boulevard of Broken Dreams               73            262333
# 1                  In The End               66            216933
# 2                  By The Way               74            216933
# 3           How You Remind Me               56            223826
# 4            Bring Me To Life               80            235893
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.005520         0.496   0.682          0.000029    0.0589    -4.095
# 1      0.010300         0.542   0.853          0.000000    0.1080    -6.407
# 2      0.026400         0.451   0.970          0.003550    0.1020    -4.938
# 3      0.000954         0.447   0.766          0.000000    0.1130    -5.065
# 4      0.008950         0.316   0.945          0.000002    0.3960    -3.169
#
#    speechiness    tempo  audio_valence
# 0       0.0294  167.060          0.474
# 1       0.0498  105.256          0.370
# 2       0.1070  122.444          0.198
# 3       0.0313  172.011          0.574
# 4       0.1240  189.931          0.320

# %%
print('До того, как из датасета были убраны выбросы было {} значений.'.format(df1.shape[0]))
print('После {} значений.'.format(df.shape[0]))
# Out:
# До того, как из датасета были убраны выбросы было 18835 значений.
# После 9106 значений.

# %% [markdown]
# Подготовим к масштабированию и выполним его

# %%
clustering = df.copy()

# %%
clustering = df.drop(columns=['song_name'])
clustering
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability  energy  \
# 0                  73            262333      0.005520         0.496   0.682
# 1                  66            216933      0.010300         0.542   0.853
# 2                  74            216933      0.026400         0.451   0.970
# 3                  56            223826      0.000954         0.447   0.766
# 4                  80            235893      0.008950         0.316   0.945
# ...               ...               ...           ...           ...     ...
# 9101               55            114582      0.898000         0.370   0.136
# 9102               62            195106      0.395000         0.644   0.523
# 9103               60            205666      0.765000         0.495   0.161
# 9104               23            182211      0.847000         0.719   0.325
# 9105               60            193533      0.911000         0.640   0.381
#
#       instrumentalness  liveness  loudness  speechiness    tempo  \
# 0             0.000029    0.0589    -4.095       0.0294  167.060
# 1             0.000000    0.1080    -6.407       0.0498  105.256
# 2             0.003550    0.1020    -4.938       0.1070  122.444
# 3             0.000000    0.1130    -5.065       0.0313  172.011
# 4             0.000002    0.3960    -3.169       0.1240  189.931
# ...                ...       ...       ...          ...      ...
# 9101          0.000263    0.0999   -13.528       0.0433  146.081
# 9102          0.000000    0.0930    -7.660       0.0378   95.966
# 9103          0.000001    0.1050   -14.078       0.0301   94.286
# 9104          0.000000    0.1250   -12.222       0.0355  130.534
# 9105          0.000254    0.1040   -11.790       0.0302   91.490
#
#       audio_valence
# 0            0.4740
# 1            0.3700
# 2            0.1980
# 3            0.5740
# 4            0.3200
# ...             ...
# 9101         0.0592
# 9102         0.4450
# 9103         0.2650
# 9104         0.2860
# 9105         0.5810
#
# [9106 rows x 11 columns]

# %%
mms = MinMaxScaler()
mms.fit(clustering)
data_transformed = mms.transform(clustering)
data_transformed = pd.DataFrame(data=data_transformed , columns = clustering.columns)
data_transformed
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability    energy  \
# 0                0.73          0.720193      0.005601      0.377407  0.670618
# 1                0.66          0.512444      0.010454      0.436457  0.849995
# 2                0.74          0.512444      0.026799      0.319641  0.972726
# 3                0.56          0.543986      0.000965      0.314506  0.758733
# 4                0.80          0.599205      0.009083      0.146341  0.946502
# ...               ...               ...           ...           ...       ...
# 9101             0.55          0.044089      0.911675      0.215661  0.097871
# 9102             0.62          0.412565      0.401013      0.567394  0.503829
# 9103             0.60          0.460887      0.776649      0.376123  0.124095
# 9104             0.23          0.353558      0.859898      0.663671  0.296129
# 9105             0.60          0.405367      0.924873      0.562259  0.354873
#
#       instrumentalness  liveness  loudness  speechiness     tempo  \
# 0             0.002774  0.114606  0.676195     0.029338  0.801612
# 1             0.000000  0.234333  0.525654     0.114837  0.370351
# 2             0.334906  0.219703  0.621305     0.354568  0.490287
# 3             0.000000  0.246525  0.613036     0.037301  0.836159
# 4             0.000175  0.936601  0.736489     0.425817  0.961203
# ...                ...       ...       ...          ...       ...
# 9101          0.024811  0.214582  0.061987     0.087594  0.655223
# 9102          0.000000  0.197757  0.444068     0.064543  0.305526
# 9103          0.000125  0.227018  0.026175     0.032272  0.293804
# 9104          0.000000  0.275786  0.147024     0.054904  0.546738
# 9105          0.023962  0.224579  0.175153     0.032691  0.274293
#
#       audio_valence
# 0          0.463666
# 1          0.354296
# 2          0.173415
# 3          0.568830
# 4          0.301714
# ...             ...
# 9101       0.027448
# 9102       0.433169
# 9103       0.243874
# 9104       0.265959
# 9105       0.576191
#
# [9106 rows x 11 columns]

# %% [markdown]
# ## Теперь перейдём к кластеризации

# %% [markdown]
# Посмотрим на количество кластеров с помощью метода локтя

# %%
Sum_of_squared_distances = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Сумма квадратов расстояний')
plt.show()

# %% [markdown]
# Как видно из графика оптимальное количество кластеров 3

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++')
y_kmeans = kmeans.fit_predict(data_transformed)

# %%
data_transformed['cluster'] = y_kmeans 
data_transformed
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability    energy  \
# 0                0.73          0.720193      0.005601      0.377407  0.670618
# 1                0.66          0.512444      0.010454      0.436457  0.849995
# 2                0.74          0.512444      0.026799      0.319641  0.972726
# 3                0.56          0.543986      0.000965      0.314506  0.758733
# 4                0.80          0.599205      0.009083      0.146341  0.946502
# ...               ...               ...           ...           ...       ...
# 9101             0.55          0.044089      0.911675      0.215661  0.097871
# 9102             0.62          0.412565      0.401013      0.567394  0.503829
# 9103             0.60          0.460887      0.776649      0.376123  0.124095
# 9104             0.23          0.353558      0.859898      0.663671  0.296129
# 9105             0.60          0.405367      0.924873      0.562259  0.354873
#
#       instrumentalness  liveness  loudness  speechiness     tempo  \
# 0             0.002774  0.114606  0.676195     0.029338  0.801612
# 1             0.000000  0.234333  0.525654     0.114837  0.370351
# 2             0.334906  0.219703  0.621305     0.354568  0.490287
# 3             0.000000  0.246525  0.613036     0.037301  0.836159
# 4             0.000175  0.936601  0.736489     0.425817  0.961203
# ...                ...       ...       ...          ...       ...
# 9101          0.024811  0.214582  0.061987     0.087594  0.655223
# 9102          0.000000  0.197757  0.444068     0.064543  0.305526
# 9103          0.000125  0.227018  0.026175     0.032272  0.293804
# 9104          0.000000  0.275786  0.147024     0.054904  0.546738
# 9105          0.023962  0.224579  0.175153     0.032691  0.274293
#
#       audio_valence  cluster
# 0          0.463666        1
# 1          0.354296        1
# 2          0.173415        1
# 3          0.568830        1
# 4          0.301714        1
# ...             ...      ...
# 9101       0.027448        0
# 9102       0.433169        0
# 9103       0.243874        0
# 9104       0.265959        0
# 9105       0.576191        0
#
# [9106 rows x 12 columns]

# %% [markdown]
# Посмотрим на средние значения и распределения

# %%
clusters_table = pd.pivot_table(data_transformed, index=['cluster'])
clusters_table
# Out:
#          acousticness  audio_valence  danceability    energy  \
# cluster
# 0            0.665780       0.458698      0.483992  0.395477
# 1            0.088091       0.357050      0.492661  0.711782
# 2            0.174705       0.765536      0.651446  0.732580
#
#          instrumentalness  liveness  loudness  song_duration_ms  \
# cluster
# 0                0.054452  0.319419  0.320241          0.466222
# 1                0.058587  0.377756  0.559923          0.522982
# 2                0.046943  0.327805  0.548441          0.488542
#
#          song_popularity  speechiness     tempo
# cluster
# 0               0.477441     0.125988  0.436657
# 1               0.519771     0.247055  0.505161
# 2               0.504885     0.243640  0.469947

# %%
color = ['red','blue','green']
fig, axes = plt.subplots(len(data_transformed.columns)-1, 3, figsize=(20, 40))
for i in range(len(data_transformed.columns)-1):
    for j in range(3):
        sns.histplot(ax=axes[i,j], data=data_transformed.loc[data_transformed['cluster'] == j][data_transformed.columns[i]], kde=True, color = color[j])

# %% [markdown]
# Очень подозрительно выглядит параметр инструменальность, поэтому избавимся от него и проведем кластеризацию заново

# %%
data_transformed = data_transformed.drop(columns=['instrumentalness','cluster'])

# %%
Sum_of_squared_distances = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Сумма квадратов расстояний')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++')
y_kmeans = kmeans.fit_predict(data_transformed)
data_transformed['cluster'] = y_kmeans 
data_transformed
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability    energy  \
# 0                0.73          0.720193      0.005601      0.377407  0.670618
# 1                0.66          0.512444      0.010454      0.436457  0.849995
# 2                0.74          0.512444      0.026799      0.319641  0.972726
# 3                0.56          0.543986      0.000965      0.314506  0.758733
# 4                0.80          0.599205      0.009083      0.146341  0.946502
# ...               ...               ...           ...           ...       ...
# 9101             0.55          0.044089      0.911675      0.215661  0.097871
# 9102             0.62          0.412565      0.401013      0.567394  0.503829
# 9103             0.60          0.460887      0.776649      0.376123  0.124095
# 9104             0.23          0.353558      0.859898      0.663671  0.296129
# 9105             0.60          0.405367      0.924873      0.562259  0.354873
#
#       liveness  loudness  speechiness     tempo  audio_valence  cluster
# 0     0.114606  0.676195     0.029338  0.801612       0.463666        2
# 1     0.234333  0.525654     0.114837  0.370351       0.354296        2
# 2     0.219703  0.621305     0.354568  0.490287       0.173415        2
# 3     0.246525  0.613036     0.037301  0.836159       0.568830        2
# 4     0.936601  0.736489     0.425817  0.961203       0.301714        2
# ...        ...       ...          ...       ...            ...      ...
# 9101  0.214582  0.061987     0.087594  0.655223       0.027448        0
# 9102  0.197757  0.444068     0.064543  0.305526       0.433169        0
# 9103  0.227018  0.026175     0.032272  0.293804       0.243874        0
# 9104  0.275786  0.147024     0.054904  0.546738       0.265959        0
# 9105  0.224579  0.175153     0.032691  0.274293       0.576191        0
#
# [9106 rows x 11 columns]

# %%
clusters_table = pd.pivot_table(data_transformed, index=['cluster'])
clusters_table
# Out:
#          acousticness  audio_valence  danceability    energy  liveness  \
# cluster
# 0            0.665980       0.458268      0.483677  0.395186  0.319477
# 1            0.175213       0.766097      0.650979  0.732359  0.326526
# 2            0.087968       0.357718      0.493718  0.712055  0.378947
#
#          loudness  song_duration_ms  song_popularity  speechiness     tempo
# cluster
# 0        0.320285          0.466356         0.477695     0.126013  0.436267
# 1        0.547803          0.488405         0.503520     0.242258  0.470442
# 2        0.560416          0.522935         0.521029     0.248448  0.504737

# %%
fig, axes = plt.subplots(len(data_transformed.columns)-1, 3, figsize=(20, 40))
for i in range(len(data_transformed.columns)-1):
    for j in range(3):
        sns.histplot(ax=axes[i,j], data=data_transformed.loc[data_transformed['cluster'] == j][data_transformed.columns[i]], kde=True, color = color[j])

# %% [markdown]
# Разберёмся с каждым параметром отдельно

# %%
name = 'acousticness'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#             acousticness
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.655991     0.172588     0.086651
# std       0.188149     0.168278     0.106799
# min       0.049200     0.000003     0.000003
# 25%       0.523000     0.033900     0.006225
# 50%       0.671000     0.119000     0.039500
# 75%       0.809750     0.267000     0.130500
# max       0.985000     0.849000     0.569000

# %% [markdown]
# Как можно заметить по акустичности
# - 0 кластер: большая часть песен является не акустичной
# - 1 кластер: более склонна к синтезу акустики и электроники. а также просто электроники
# - 2 кластер: большая часть песен является не акустичной, но больше чем в первом кластере

# %%
name = 'danceability'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#             danceability
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.578784     0.709113     0.586607
# std       0.138642     0.114753     0.147396
# min       0.207000     0.266000     0.202000
# 25%       0.484000     0.634000     0.487000
# 50%       0.585000     0.714000     0.585000
# 75%       0.679000     0.790000     0.688000
# max       0.939000     0.981000     0.972000

# %% [markdown]
# Как можно заметить по танцевальности
# - 0 кластер: более танцевальная музыка
# - 1 кластер: средней танцевальности
# - 2 кластер: средней танцевальности, но меньшей, чем у 1 кластера

# %%
name = 'energy'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#                energy
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.419431     0.740858     0.721502
# std       0.145460     0.133944     0.155907
# min       0.042700     0.268000     0.257000
# 25%       0.313000     0.649000     0.598000
# 50%       0.422000     0.751000     0.727000
# 75%       0.519000     0.844000     0.849000
# max       0.902000     0.994000     0.996000

# %% [markdown]
# Как можно заметить по энергичности
# - 0 кластер: высокая энергичность
# - 1 кластер: чуть ниже среднего
# - 2 кластер: высокая энергичность, чуть больше, чем у 0 кластера

# %%
name = 'liveness'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#               liveness
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.142918     0.145808     0.167306
# std       0.075655     0.092771     0.095932
# min       0.021900     0.011900     0.018600
# 25%       0.097725     0.078500     0.096700
# 50%       0.115000     0.111000     0.129000
# 75%       0.161750     0.192000     0.226000
# max       0.422000     0.422000     0.421000

# %% [markdown]
# Как можно заметить по живости все более-менее искуственные, живого звука мало

# %%
name = 'loudness'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#               loudness
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean     -9.561063    -6.066835    -5.873136
# std       2.440220     2.350774     2.073797
# min     -14.480000   -14.331000   -14.329000
# 25%     -11.382750    -7.325000    -7.082000
# 50%      -9.487500    -5.726000    -5.622000
# 75%      -7.698500    -4.404000    -4.450000
# max      -1.458000    -0.739000     0.878000

# %% [markdown]
# Как можно заметить по громкости
# - 0 кластер: более склонен к повышенной громкости
# - 1 кластер: более склонен к меньшей и средней громкости
# - 2 кластер: более склонен к повышенной громкости

# %%
name = 'speechiness'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#             speechiness
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.052467     0.080203     0.081680
# std       0.039743     0.058370     0.058054
# min       0.022900     0.022400     0.022800
# 25%       0.031100     0.038900     0.039300
# 50%       0.037400     0.055800     0.058600
# 75%       0.054800     0.100000     0.106000
# max       0.260000     0.261000     0.261000

# %% [markdown]
# Как можно заметить по речевости
# - 0 кластер: мало слов
# - 1 кластер: мало слов
# - 2 кластер: чуть больше слов, чем в 0 и 1 кластере

# %%
name = 'tempo'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#                tempo
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean    114.702377   119.600093   124.514859
# std      29.073758    24.788962    27.634287
# min      52.181000    62.493000    60.048000
# 25%      91.103500   100.010000   101.968500
# 50%     112.716500   118.025000   124.020000
# 75%     133.696500   132.752000   143.540000
# max     195.092000   193.773000   195.491000

# %% [markdown]
# Как можно заметить по темпу
# - 0 кластер: средний и медлительный темп музыки
# - 1 кластер: средний и медлительный темп музыки
# - 2 кластер: средний темп музыки

# %%
name = 'audio_valence'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#            audio_valence
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean      0.468868     0.761582     0.373254
# std       0.234497     0.130611     0.144548
# min       0.034100     0.363000     0.033100
# 25%       0.283000     0.662000     0.268000
# 50%       0.445000     0.764000     0.383000
# 75%       0.637500     0.871000     0.483000
# max       0.978000     0.984000     0.769000

# %% [markdown]
# Как можно заметить по валентности
# - 0 кластер: позитивная музыка в большей части
# - 1 кластер: средняя и более склонная к негативной
# - 2 кластер: средняя

# %%
name = 'song_duration_ms'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i])

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#           song_duration_ms
#            cluster_0      cluster_1      cluster_2
# count    2022.000000    3673.000000    3411.000000
# mean   206861.235410  211679.712769  219225.516564
# std     44795.816281   39511.456538   38125.487748
# min    106760.000000  104947.000000  106046.000000
# 25%    173878.500000  184519.000000  193645.000000
# 50%    204029.500000  209014.000000  215093.000000
# 75%    236477.000000  235066.000000  241200.000000
# max    321973.000000  322933.000000  323480.000000

# %%
name = 'song_popularity'
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
        sns.histplot(ax=axes[i], data=data_transformed.loc[data_transformed['cluster'] == i][name], kde=True, color = color[i], bins=15)

print(name.center(35))
cluster_0 = df.loc[data_transformed['cluster'] == 0][name].describe()
cluster_1 = df.loc[data_transformed['cluster'] == 1][name].describe()
cluster_2 = df.loc[data_transformed['cluster'] == 2][name].describe()
cluster = pd.DataFrame()
cluster['cluster_0'] = cluster_0
cluster['cluster_1'] = cluster_1
cluster['cluster_2'] = cluster_2
cluster
# Out:
#           song_popularity
#          cluster_0    cluster_1    cluster_2
# count  2022.000000  3673.000000  3411.000000
# mean     47.769535    50.352028    52.102902
# std      19.572681    20.588984    21.188450
# min       0.000000     0.000000     0.000000
# 25%      35.000000    39.000000    41.000000
# 50%      50.000000    53.000000    55.000000
# 75%      62.000000    65.000000    67.000000
# max      96.000000   100.000000    98.000000

# %% [markdown]
# По популярности:
# Как можно заметить у 0 и 2 много песен с около нулевой популярностью, также большее среднее значение, чем у 1 кластера
# Но если заказчик хочет с большей вероятностью получить нормальный по популярности трек, то нужно следовать 1 кластеру

# %% [markdown]
# ## Построение предсказательной модели

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

dataLR = df.drop(columns = ['song_name'])
target = 'song_popularity'
X = dataLR.drop([target],axis=1)
Y = dataLR[target]
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=100)
Train_X.reset_index(drop=True,inplace=True)

print('Изначальные данные  ---> ',X.shape,Y.shape,'\nДанные для тренировки  ---> ',Train_X.shape,Train_Y.shape,'\nДанные для теста   ---> ', Test_X.shape,'', Test_Y.shape)
# Out:
# Изначальные данные  --->  (9106, 10) (9106,)
# Данные для тренировки  --->  (7284, 10) (7284,)
# Данные для теста   --->  (1822, 10)  (1822,)

# %%
std = StandardScaler()

print('\033[1mСтандартизация на тренировочных данных'.center(120))
Train_X_std = std.fit_transform(Train_X)
Train_X_std = pd.DataFrame(Train_X_std, columns=X.columns)
display(Train_X_std.describe())

print('\n','\033[1mСтандартизация на тестовых данных'.center(120))
Test_X_std = std.transform(Test_X)
Test_X_std = pd.DataFrame(Test_X_std, columns=X.columns)
display(Test_X_std.describe())
# Out:
#                                        Стандартизация на тренировочных данных
#        song_duration_ms  acousticness  danceability        energy  \
# count      7.284000e+03  7.284000e+03  7.284000e+03  7.284000e+03
# mean      -3.064850e-16  4.381677e-17 -6.835096e-16  3.471581e-16
# std        1.000069e+00  1.000069e+00  1.000069e+00  1.000069e+00
# min       -2.667318e+00 -9.191336e-01 -2.930942e+00 -3.193682e+00
# 25%       -6.688339e-01 -8.188549e-01 -6.365370e-01 -6.741896e-01
# 50%       -6.125602e-02 -4.172269e-01  6.472019e-02  1.169430e-01
# 75%        6.100700e-01  5.903286e-01  7.319358e-01  7.932129e-01
# max        2.715631e+00  2.743002e+00  2.359125e+00  1.727601e+00
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      7.284000e+03  7.284000e+03  7.284000e+03  7.284000e+03
# mean      -7.468551e-18 -3.751652e-16 -1.357905e-16  2.521474e-16
# std        1.000069e+00  1.000069e+00  1.000069e+00  1.000069e+00
# min       -3.541932e-01 -1.548487e+00 -2.837697e+00 -9.303423e-01
# 25%       -3.541932e-01 -6.913656e-01 -5.763161e-01 -6.833411e-01
# 50%       -3.524356e-01 -3.761026e-01  1.855781e-01 -4.202312e-01
# 75%       -2.700241e-01  4.558414e-01  7.343775e-01  2.724460e-01
# max        6.206053e+00  2.940727e+00  2.817091e+00  3.340272e+00
#
#               tempo  audio_valence
# count  7.284000e+03   7.284000e+03
# mean  -4.748093e-16   9.235854e-17
# std    1.000069e+00   1.000069e+00
# min   -2.253468e+00  -2.149970e+00
# 25%   -7.600343e-01  -7.971743e-01
# 50%   -1.578518e-02  -8.493438e-03
# 75%    6.462943e-01   8.258479e-01
# max    2.782500e+00   1.797171e+00
#                                           Стандартизация на тестовых данных
#        song_duration_ms  acousticness  danceability       energy  \
# count       1822.000000   1822.000000   1822.000000  1822.000000
# mean           0.025053      0.009600     -0.007152     0.022895
# std            0.991621      1.007500      0.992402     1.027001
# min           -2.590023     -0.919112     -2.944558    -3.095081
# 25%           -0.661167     -0.820249     -0.677387    -0.656121
# 50%           -0.034456     -0.409791      0.044295     0.189216
# 75%            0.623488      0.586611      0.709809     0.860324
# max            2.713660      2.739285      2.338700     1.727601
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       1822.000000  1822.000000  1822.000000  1822.000000  1822.000000
# mean          -0.033759    -0.007581     0.005228     0.019575    -0.003902
# std            0.949056     0.988800     1.005255     1.004341     1.021959
# min           -0.354193    -1.439021    -2.812660    -0.914234    -2.526064
# 25%           -0.354193    -0.686713    -0.604851    -0.681551    -0.789437
# 50%           -0.352556    -0.403469     0.193126    -0.391593    -0.019156
# 75%           -0.277605     0.488681     0.739440     0.313165     0.629792
# max            6.206053     2.929780     2.049029     3.340272     2.761237
#
#        audio_valence
# count    1822.000000
# mean        0.001560
# std         1.004155
# min        -2.143743
# 25%        -0.817929
# 50%         0.039243
# 75%         0.813395
# max         1.780567

# %% [markdown]
# Сделаем отображение данных

# %%
rc=np.random.choice(Train_X_std.loc[:,Train_X_std.nunique()>=50].columns.values,3,replace=False)
def Evaluate(n, pred1,pred2):
    plt.figure(figsize=[15,6])
    for e,i in enumerate(rc):
        plt.subplot(2,3,e+1)
        plt.scatter(y=Train_Y, x=Train_X_std[i], label='Реальные данные')
        plt.scatter(y=pred1, x=Train_X_std[i], label='Предсказанные данные')
        plt.legend()
    plt.show()

# %% [markdown]
# Множественная линейная регрессия

# %%
MLR = LinearRegression().fit(Train_X,Train_Y)
pred1 = MLR.predict(Train_X)
pred2 = MLR.predict(Test_X)

print('Коэффициенты регрессии равны ',MLR.coef_)
print('Константа модели ',MLR.intercept_)

Evaluate(0, pred1, pred2)
# Out:
# Коэффициенты регрессии равны  [ 1.21430989e-05 -4.96019914e+00  1.19156674e+01 -1.20185053e+01
#  -3.63133646e+02 -5.86524953e+00  1.07953582e+00 -3.45259801e+00
#  -2.05638946e-03 -6.03771376e+00]
# Константа модели  61.66497429968682

# %%
print('Значение R2 для данной модели ',round(r2_score(Train_Y, pred1),20))
# Out:
# Значение R2 для данной модели  0.031121615983022207

# %% [markdown]
# Модель полиномиальной регрессии

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(Train_X_std)
X_poly1 = poly_reg.fit_transform(Test_X_std)
PR = LinearRegression()
PR.fit(X_poly, Train_Y)

pred1 = PR.predict(X_poly)
pred2 = PR.predict(X_poly1)

print('The Coeffecient of the Regresion Model was found to be ',PR.coef_)
print('The Intercept of the Regresion Model was found to be ',PR.intercept_)

Evaluate(4, pred1, pred2)
# Out:
# The Coeffecient of the Regresion Model was found to be  [-1.21510984e-17  3.96598573e-01 -2.88970664e-01  1.74952657e+00
#  -2.01204960e+00 -2.10902866e+00 -5.56430925e-01  2.90017910e+00
#  -9.67026829e-02 -2.33194555e-01 -1.67512641e+00 -4.16796010e-01
#  -2.16043508e-01 -2.82060393e-01 -3.05783803e-01 -1.09260842e-01
#  -1.14717463e-01 -2.48257973e-01  4.00539802e-01  2.72533345e-01
#  -1.82957276e-04 -1.01783382e+00  4.02039964e-01 -2.00376338e-02
#   1.58842000e-01 -7.96363901e-01 -5.18996980e-02 -6.16875154e-01
#   2.05438975e-01 -1.56453251e+00 -3.90613176e-01 -2.67707267e-01
#   5.34910640e-02  1.75458672e-01  1.07079035e+00 -1.59616864e-01
#   2.01000982e-02 -7.49082531e-02  3.01834478e-01  3.85127511e-01
#  -5.26393345e-01 -9.92456808e-01 -1.37235374e+00 -5.11248041e-01
#  -5.02758655e-02  3.99535436e-01  9.45807122e-03 -2.00829357e-01
#  -1.39254907e-01  3.67940854e-01 -1.92217475e-01  8.87101080e-02
#   2.07941125e-01  7.39444668e-02 -9.79605034e-02  1.73430184e-01
#   6.55951830e-01  5.97063748e-01  3.59834708e-01 -2.52204996e-01
#  -4.08798568e-02  2.33926573e-01  3.66099955e-02  6.02752259e-01
#  -5.07576227e-01 -8.09360684e-02]
# The Intercept of the Regresion Model was found to be  51.04377673367189

# %%
print('Значение R2 для данной модели ',round(r2_score(Train_Y, pred1),20))
# Out:
# Значение R2 для данной модели  0.04798266123169226
